# %%
import pip

def import_or_install(package):
    try:
        __import__(package)
    except ImportError:
        pip.main(['install', package])

import_or_install("numpy")
import_or_install("pandas")
import_or_install("pickle")

import numpy as np
import pandas as pd
import pickle

# %%
def load_csv(filepath):
    data = []
    col = []

    checkcol = False
    with open(filepath) as f:
        for val in f.readlines():
            val = val.split(',')
            if checkcol is False:
                col = val
                checkcol = True
            else:
                data.append(val)
        df = pd.DataFrame(data=data, columns=col)
        return df

# %%
num_records = 100

data = {
    'Order ID': np.arange(1, num_records +1),
    'Product': np.random.choice(['Product A', 'Product B', 'Product C'], num_records),
    'Quantity Ordered': np.random.randint(1,100,num_records),
    'Price Each': np.round(np.random.uniform(5.0, 100.0, num_records),2),
    'Order Date': pd.date_range(start='1/1/2021',periods=num_records,freq='D'),
    'Region': np.random.choice(['North', 'South', 'East', 'West'], num_records),
    'Total Sales': lambda x: x['Quantity Ordered']*x['Price Each']
}

df = pd.DataFrame(data)
df['Total Sales'] = df.apply(lambda x: x['Quantity Ordered']*x['Price Each'],axis=1)

# %%
#numpy genfromtext example

data = np.genfromtxt('100 Sales Records.csv', delimiter=',', dtype=None,names=True, encoding='utf-8')

pd.DataFrame(data)
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
file_path = '100_Sales_Records.csv'
df.to_csv
# Out:
# <bound method NDFrame.to_csv of     Order ID    Product  Quantity Ordered  Price Each Order Date Region  \
# 0          1  Product B                86       24.74 2021-01-01   West
# 1          2  Product C                66       64.03 2021-01-02   East
# 2          3  Product C                22       43.58 2021-01-03  South
# 3          4  Product A                61       44.98 2021-01-04  South
# 4          5  Product A                82       17.83 2021-01-05  South
# ..       ...        ...               ...         ...        ...    ...
# 95        96  Product A                98       15.80 2021-04-06  South
# 96        97  Product B                17       17.46 2021-04-07   West
# 97        98  Product A                23       87.74 2021-04-08  South
# 98        99  Product A                12       34.44 2021-04-09  South
# 99       100  Product C                68       44.73 2021-04-10  South
#
#     Total Sales
# 0       2127.64
# 1       4225.98
# 2        958.76
# ...

# %%
#using pickle

with open('test.pkl', 'wb') as f:
    pickle.dump(df, f)

# %%
with open('test.pkl', 'rb') as f:
    new_df = pickle.load(f)
    print(new_df)
# Out:
#     Order ID    Product  Quantity Ordered  Price Each Order Date Region  \
# 0          1  Product B                86       24.74 2021-01-01   West
# 1          2  Product C                66       64.03 2021-01-02   East
# 2          3  Product C                22       43.58 2021-01-03  South
# 3          4  Product A                61       44.98 2021-01-04  South
# 4          5  Product A                82       17.83 2021-01-05  South
# ..       ...        ...               ...         ...        ...    ...
# 95        96  Product A                98       15.80 2021-04-06  South
# 96        97  Product B                17       17.46 2021-04-07   West
# 97        98  Product A                23       87.74 2021-04-08  South
# 98        99  Product A                12       34.44 2021-04-09  South
# 99       100  Product C                68       44.73 2021-04-10  South
#
#     Total Sales
# 0       2127.64
# 1       4225.98
# 2        958.76
# 3       2743.78
# ...
